# %%
from IPython.display import display, Image
import os, warnings
import re
warnings.filterwarnings(action='ignore')

# %%
from selenium import webdriver
from bs4 import BeautifulSoup

# %%
driver = webdriver.Chrome('chromedriver_90.exe')
## https://www.amazon.com/
url = 'https://coronaboard.kr/'
driver.get(url)
# import time
# time.sleep(3) # 홈페이지 로딩 시간 3초

# %%
sel_btn = driver.find_element_by_xpath('//*[@id="global-slide"]/div/div[2]/div/div/button')
sel_btn.click()

# %%
#치료증 클릭
sel_btn1 = driver.find_element_by_xpath('//*[@id="bs-select-1"]/ul/li[1]')
sel_btn1.click()

# %%
#인구수 클릭
sel_btn1 = driver.find_element_by_xpath('//*[@id="bs-select-1"]/ul/li[6]')
sel_btn1.click()

# %%
from selenium.webdriver import ActionChains #이동하는
some_tag = driver.find_element_by_id('show-more') 
ActionChains(driver).move_to_element(some_tag).perform()
some_tag.click()

# %%
some_tag = driver.find_element_by_id('show-more')
ActionChains(driver).move_to_element(some_tag).perform()
some_tag.click()
# Out:
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# <ipython-input-12-75954ecbd849> in <module>
#       1 some_tag = driver.find_element_by_id('show-more')
# ----> 2 ActionChains(driver).move_to_element(some_tag).perform()
#       3 some_tag.click()
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\common\action_chains.py in perform(self)
#      78         """
#      79         if self._driver.w3c:
# ---> 80             self.w3c_actions.perform()
#      81         else:
#      82             for action in self._actions:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\common\actions\action_builder.py in perform(self)
#      74             if encoded['actions']:
#      75                 enc["actions"].append(encoded)
# ---> 76         self.driver.execute(Command.W3C_ACTIONS, enc)
#      77
#      78     def clear_actions(self):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# ElementNotInteractableException: Message: element not interactable: [object HTMLButtonElement] has no size and location
#   (Session info: chrome=91.0.4472.114)

# %%
pop_sort = driver.find_element_by_xpath('//*[@id="country-table"]/div/div/table/thead/tr/th[10]')
pop_sort.click()

# %%
sel_country = driver.find_elements_by_xpath('//*[@id="country-table"]/div/div/table/tbody/tr/td[2]')
len(sel_country)
# Out:
# 221

# %%
for one in sel_country:
    one.text
#     print(one.text)

# %%
all_data = []
for i in range(2, 11):
    tmp = '//*[@id="country-table"]/div/div/table/tbody/tr/td[{}]'.format(i)
    # print(tmp)
    sel_ele = driver.find_elements_by_xpath(tmp)
    
    column_data = []
    for one in sel_ele:
        # print(one.text)
        column_data.append(one.text)
    print( len(sel_ele) )
    all_data.append(column_data)
    print(column_data)
    print()
all_data
# Out:
# 221
# ['중국🇨🇳', '인도🇮🇳', '미국🇺🇸', '인도네시아🇮🇩', '파키스탄🇵🇰', '브라질🇧🇷', '나이지리아🇳🇬', '방글라데시🇧🇩', '러시아🇷🇺', '멕시코🇲🇽', '일본🇯🇵*', '에티오피아🇪🇹', '필리핀🇵🇭', '이집트🇪🇬', '베트남🇻🇳', '콩고민주공화국🇨🇩', '터키🇹🇷', '이란🇮🇷', '독일🇩🇪', '태국🇹🇭', '영국🇬🇧', '프랑스🇫🇷', '이탈리아🇮🇹', '탄자니아🇹🇿', '남아프리카 공화국🇿🇦', '미얀마🇲🇲', '케냐🇰🇪', '대한민국🇰🇷', '콜롬비아🇨🇴', '스페인🇪🇸', '우간다🇺🇬', '아르헨티나🇦🇷', '알제리🇩🇿', '수단🇸🇩', '우크라이나🇺🇦', '이라크🇮🇶', '아프가니스탄🇦🇫', '폴란드🇵🇱', '캐나다🇨🇦', '모로코🇲🇦', '사우디아라비아🇸🇦', '우즈베키스탄🇺🇿', '페루🇵🇪', '앙골라🇦🇴', '말레이시아🇲🇾', '모잠비크🇲🇿', '가나🇬🇭', '예멘🇾🇪', '네팔🇳🇵', '베네수엘라🇻🇪', '마다가스카르🇲🇬', '카메룬🇨🇲', '코트디부아르🇨🇮', '호주🇦🇺', '니제르🇳🇪', '대만🇹🇼', '스리랑카🇱🇰', '부르키나파소🇧🇫', '말리🇲🇱', '루마니아🇷🇴', '말라위🇲🇼', '칠레🇨🇱', '카자흐스탄🇰🇿', '잠비아🇿🇲', '과테말라🇬🇹', '에콰도르🇪🇨', '시리아🇸🇾', '네덜란드🇳🇱', '세네갈🇸🇳', '캄보디아🇰🇭', '차드🇹🇩', '소말리아🇸🇴', '짐바브웨🇿🇼', '기니🇬🇳', '르완다🇷🇼', '베냉🇧🇯', '부룬디🇧🇮', '튀니지🇹🇳', '볼리비아🇧🇴', '벨기에🇧🇪', '아이티🇭🇹', '쿠바🇨🇺', '남수단🇸🇸', '도미니카 공화국🇩🇴', '체코🇨🇿', '그리스🇬🇷', '요르단🇯🇴', '포르투갈🇵🇹', '아제르바이잔🇦🇿', '스웨덴🇸🇪', '온두라스🇭🇳', '아랍에미레이트🇦🇪', '헝가리🇭🇺', '타지키스탄🇹🇯', '벨라루스🇧🇾', '오스트리아🇦🇹', '파푸아뉴기니🇵🇬', '세르비아🇷🇸', '이스라엘🇮🇱', '스위스🇨🇭', '토고🇹🇬', '시에라리온🇸🇱', '홍콩🇭🇰', '라오스🇱🇦', '파라과이🇵🇾', '불가리아🇧🇬', '리비아🇱🇾', '레바논🇱🇧', '니카라과🇳🇮', '키르기스스탄🇰🇬', '엘살바도르🇸🇻', '싱가포르🇸🇬', '덴마크🇩🇰', '핀란드🇫🇮', '콩고공화국🇨🇬', '슬로바키아🇸🇰', '노르웨이🇳🇴', '오만🇴🇲', '팔레스타인🇵🇸', '코스타리카🇨🇷', '라이베리아🇱🇷', '아일랜드🇮🇪', '중앙아프리카 공화국🇨🇫', '뉴질랜드🇳🇿', '모리타니🇲🇷', '파나마🇵🇦', '쿠웨이트🇰🇼', '크로아티아🇭🇷', '몰도바🇲🇩', '조지아🇬🇪', '에리트레아🇪🇷', '우루과이🇺🇾', '보스니아 헤르체고비나🇧🇦', '몽골🇲🇳', '아르메니아🇦🇲', '자메이카🇯🇲', '카타르🇶🇦', '알바니아🇦🇱', '리투아니아🇱🇹', '나미비아🇳🇦', '감비아🇬🇲', '보츠와나🇧🇼', '가봉🇬🇦', '레소토🇱🇸', '북마케도니아🇲🇰', '슬로베니아🇸🇮', '기니비사우🇬🇼', '라트비아🇱🇻', '코소보🇽🇰', '바레인🇧🇭', '적도 기니🇬🇶', '트리니다드 토바고🇹🇹', '에스토니아🇪🇪', '
#
# 221
# ['5.1', '1.3', '1.8', '2.7', '2.3', '2.8', '1.3', '1.6', '2.4', '9.3', '1.8', '1.6', '1.7', '5.7', '0.5', '2.3', '0.9', '2.7', '2.4', '0.8', '2.8', '1.9', '3.0', '4.1', '3.2', '2.2', '1.9', '1.3', '2.5', '2.1', '0.9', '2.1', '2.7', '7.5', '2.3', '1.3', '4.1', '2.6', '1.9', '1.8', '1.6', '0.7', '9.4', '2.3', '0.6', '1.2', '0.8', '19.7', '1.4', '1.1', '2.1', '1.6', '0.6', '3.0', '3.5', '4.0', '1.1', '1.2', '3.6', '3.0', '3.4', '2.1', '1.0', '1.3', '3.1', '4.8', '7.3', '1.1', '2.7', '1.0', '3.5', '5.2', '4.0', '0.7', '1.2', '1.3', '0.2', '3.7', '3.8', '2.3', '2.2', '0.7', '1.1', '1.2', '1.8', '3.0', '1.3', '2.0', '1.5', '1.3', '2.7', '0.3', '3.7', '0.7', '0.7', '1.6', '1.0', '1.0', '0.8', '1.5', '0.9', '1.7', '1.8', '0.1', '2.9', '4.3', '1.7', '1.4', '2.4', '1.7', '3.0', '0.1', '0.9', '1.0', '1.3', '3.2', '0.6', '1.1', '1.1', '1.3', '3.2', '1.8', '1.4', '1.0', '2.4', '1.6', '0.6', '2.3', '2.4', '1.4', '0.4', '1.5', '4.7', '0.5', '2.0', '2.1', '0.3', '1.9', '1.6', '1.6', '3.0', '1.6', '0.6', '3.0', '3.5', '1.7', '1.8', '1.8', '2.1', '0.5', '1.4', '2.4', '1.0', '0.2', '1.1', '0.5', '3.6', '1.3', '0.3', '0.8', '3.7', '2.3', '0.1', '-', '-', '1.6', '1.2', '10', '2.3', '0.9', '0.3', '1.4', '1.2', '1.4', '2.5', '2.0', '0.8', '0.5', '25', '0.5', '1.2', '-', '0.7', '0.9', '1.6', '-', '1.5', '1.0', '-', '0.6', '0.5', '1.0', '0.4', '3.3', '1.8', '0.9', '-', '0.3', '1.3', '-', '-', '0.6', '0.1', '1.2', '1.3', '0.7', '0.6', '1.9', '1.8', '2.2', '0.4', '1.0', '-', '0.1', '-', '-', '5', '-', '-', '1.6', '22.2']
#
# 221
# ['94.4', '96.5', '83.6', '89.9', '94.2', '90.6', '97.9', '91.7', '91.5', '79.7', '95.3', '92.8', '94.2', '74.2', '40.3', '73.7', '97.4', '88.9', '96.7', '83.3', '92.7', '96.7', '95.2', '36.0', '90.4', '90.0', '68.6', '94.7', '92.9', '94.6', '68.5', '91.4', '69.6', '82.7', '96.5', '93.2', '61.5', '92.1', '97.4', '97.6', '96.2', '96.0', 'N/A', '84.2', '90.4', '96.8', '97.8', '57.5', '89.9', '92.5', '96.0', '97.3', '98.8', '96.4', '94.7', '53.5', '83.3', '98.7', '69.8', '96.8', '94.2', '95.4', '94.1', '84.6', '90.7', '93.0', '86.4', 'N/A', '96.4', '87.9', '96.4', '48.5', '88.2', '94.7', '84.9', '98.
# [['중국🇨🇳',
#   '인도🇮🇳',
#   '미국🇺🇸',
#   '인도네시아🇮🇩',
#   '파키스탄🇵🇰',
#   '브라질🇧🇷',
#   '나이지리아🇳🇬',
#   '방글라데시🇧🇩',
#   '러시아🇷🇺',
#   '멕시코🇲🇽',
#   '일본🇯🇵*',
#   '에티오피아🇪🇹',
#   '필리핀🇵🇭',
#   '이집트🇪🇬',
#   '베트남🇻🇳',
#   '콩고민주공화국🇨🇩',
#   '터키🇹🇷',
#   '이란🇮🇷',
#   '독일🇩🇪',
#   '태국🇹🇭',
#   '영국🇬🇧',
#   '프랑스🇫🇷',
#   '이탈리아🇮🇹',
#   '탄자니아🇹🇿',
#   '남아프리카 공화국🇿🇦',
#   '미얀마🇲🇲',
#   '케냐🇰🇪',
#   '대한민국🇰🇷',
#   '콜롬비아🇨🇴',
#   '스페인🇪🇸',
#   '우간다🇺🇬',
#   '아르헨티나🇦🇷',
#   '알제리🇩🇿',
#   '수단🇸🇩',
#   '우크라이나🇺🇦',
#   '이라크🇮🇶',
#   '아프가니스탄🇦🇫',
#   '폴란드🇵🇱',
#   '캐나다🇨🇦',
#   '모로코🇲🇦',
#   '사우디아라비아🇸🇦',
#   '우즈베키스탄🇺🇿',
#   '페루🇵🇪',
#   '앙골라🇦🇴',
#   '말레이시아🇲🇾',
#   '모잠비크🇲🇿',
#   '가나🇬🇭',
#   '예멘🇾🇪',
#   '네팔🇳🇵',
#   '베네수엘라🇻🇪',
#   '마다가스카르🇲🇬',
#   '카메룬🇨🇲',
#   '코트디부아르🇨🇮',
#   '호주🇦🇺',
#   '니제르🇳🇪',
#   '대만🇹🇼',
#   '스리랑카🇱🇰',
#   '부르키나파소🇧🇫',
#   '말리🇲🇱',
#   '루마니아🇷🇴',
#   '말라위🇲🇼',
#   '칠레🇨🇱',
#   '카자흐스탄🇰🇿',
#   '잠비아🇿🇲',
#   '과테말라🇬🇹',
#   '에콰도르🇪🇨',
#   '시리아🇸🇾',
#   '네덜란드🇳🇱',
#   '세네갈🇸🇳',
#   '캄보디아🇰🇭',
#   '차드🇹🇩',
#   '소말리아🇸🇴',
#   '짐바브웨🇿🇼',
#   '기니🇬🇳',
#   '르완다🇷🇼',
#   '베냉🇧🇯',
#   '부룬디🇧🇮',
#   '튀니지🇹🇳',
#   '볼리비아🇧🇴',
#   '벨기에🇧🇪',
#   '아이티🇭🇹',
#   '쿠바🇨🇺',
#   '남수단🇸🇸',
#   '도미니카 공화국🇩🇴',
#   '체코🇨🇿',
#   '그리스🇬🇷',
#   '요르단🇯🇴',
#   '포르투갈🇵🇹',
#   '아제르바이잔🇦🇿',
#   '스웨덴🇸🇪',
#   '온두라스🇭🇳',
#   '아랍에미레이트🇦🇪',
#   '헝가리🇭🇺',
#   '타지키스탄🇹🇯',
#   '벨라루스🇧🇾',
#   '오스트리아🇦🇹',
#   '파푸아뉴기니🇵🇬',
#   '세르비아🇷🇸',
#   '이스라엘🇮🇱',
#   '스위스🇨🇭',
#   '토고🇹🇬',
#   '시에라리온🇸🇱',
#   '홍콩🇭🇰',
#   '라오스🇱🇦',
#   '파라과이🇵🇾',
#   '불가리아🇧🇬',
#   '리비아🇱🇾',
#   '레바논🇱🇧',
#   '니카라과🇳🇮',
#   '키르기스스탄🇰🇬',
#   '엘살바도르🇸🇻',
#   '싱가포르🇸🇬',
#   '덴마크🇩🇰',
#   '핀란드🇫🇮',
#   '콩고공화국🇨🇬',
#   '슬로바키아🇸🇰',
#   '노르웨이🇳🇴',
#   '오만🇴🇲',
#   '팔레스타인🇵🇸',
#   '코스타리카🇨🇷',
#   '라이베리아🇱🇷',
#   '아일랜드🇮🇪',
#   '중앙아프리카 공화국🇨🇫',
#   '뉴질랜드🇳🇿',
#   '모리타니🇲🇷',
#   '파나마🇵🇦',
#   '쿠웨이트🇰🇼',
#   '크로아티아🇭🇷',
#   '몰도바🇲🇩',
#   '조지아🇬🇪',
#   '에리트레아🇪🇷',
#   '우루과이🇺🇾',
#   '보스니아 헤르체고비나🇧🇦',
#   '몽골🇲🇳',
#   '아르메니아🇦🇲',
#   '자메이카🇯🇲',
#   '카타르🇶🇦',
#   '알바니아🇦🇱',
#   '리투아니아🇱🇹',
#   '나미비아🇳🇦',
#   '감비아🇬🇲',
#   '보츠와나🇧🇼',
#   '가봉🇬🇦',
#   '레소토🇱🇸',
#   '북마케도니아🇲🇰',
#   '슬로베니아🇸🇮',
#   '기니비사우🇬🇼',
#   '라트비아🇱🇻',
#   '코소보🇽🇰',
#   '바레인🇧🇭',
#   '적도 기니🇬🇶',
#   '트리니다드 토바고🇹🇹',
#   '에스토니아🇪🇪',
#   '동티모르🇹🇱',
#   '모리셔스🇲🇺',
#   '키프로스🇨🇾',
#   '에스와티니🇸🇿',
#   '지부티🇩🇯',
#   '피지🇫🇯',
#   '레위니옹🇷🇪',
#   '코모로🇰🇲',
#   '가이아나🇬🇾',
#   '부탄🇧🇹',
#   '솔로몬 제도🇸🇧',
#   '마카오🇲🇴',
#   '몬테네그로🇲🇪',
#   '룩셈부르크🇱🇺',
#   '서사하라🇪🇭',
#   '수리남🇸🇷',
#   '카보베르데🇨🇻',
#   '몰디브🇲🇻',
#   '몰타 공화국🇲🇹',
#   '브루나이🇧🇳',
#   '과들루프🇬🇵',
#   '벨리즈🇧🇿',
#   '바하마🇧🇸',
#   '마르티니크🇲🇶',
#   '아이슬란드🇮🇸',
#   '바누아투🇻🇺',
#   '프랑스령 기아나🇬🇫',
#   '바베이도스🇧🇧',
#   '뉴칼레도니아🇳🇨',
#   '프랑스령 폴리네시아🇵🇫',
#   '마요트🇾🇹',
#   '상투메 프린시페🇸🇹',
#   '사모아🇼🇸',
#   '세인트루시아🇱🇨',
#   '퀴라소🇨🇼',
#   '미크로네시아🇫🇲',
#   '그레나다🇬🇩',
#   '세인트빈센트 그레나딘🇻🇨',
#   '아루바🇦🇼',
#   '세이셸🇸🇨',
#   '앤티가 바부다🇦🇬',
#   '맨섬🇮🇲',
#   '안도라🇦🇩',
#   '도미니카 연방🇩🇲',
#   '케이맨 제도🇰🇾',
#   '버뮤다🇧🇲',
#   '마셜 제도🇲🇭',
#   '그린란드🇬🇱',
#   '세인트키츠 네비스🇰🇳',
#   '페로 제도🇫🇴',
#   '신트마르턴🇸🇽',
#   '모나코🇲🇨',
#   '터크스 케이커스 제도🇹🇨',
#   '세인트마틴 섬🇲🇫',
#   '리히텐슈타인🇱🇮',
#   '산마리노🇸🇲',
#   '지브롤터🇬🇮',
#   '영국령 버진아일랜드🇻🇬',
#   '카리브 네덜란드🇧🇶',
#   '앵귈라🇦🇮',
#   '생바르텔레미🇧🇱',
#   '세인트헬레나🇸🇭',
#   '생피에르 미클롱🇵🇲',
#   '몬트세랫🇲🇸',
#   '포클랜드 제도🇫🇰',
#   '바티칸 시국🇻🇦',
#   '왈리스 퓌티나🇼🇫',
#   '잔담(크루즈)🚢'],
#  ['91,629\n(+25)',
#   '29,977,861\n(+12,569)',
#   '34,419,838\n(+13,779)',
#   '2,004,445',
#   '949,838\n(+663)',
#   '17,969,806\n(+41,878)',
#   '167,292\n(+86)',
#   '856,304',
#   '5,334,204',
#   '2,478,551\n(+1,268)',
#   '785,969',
#   '275,318\n(+124)',
#   '1,364,239',
#   '277,797\n(+509)',
#   '13,530\n(+47)',
#   '37,926\n(+117)',
#   '5,375,593\n(+5,294)',
#   '3,105,620',
#   '3,730,599\n(+353)',
#   '225,365\n(+4,059)',
#   '4,640,507\n(+10,467)',
#   '5,757,798\n(+487)',
#   '4,253,460\n(+484)',
#   '509',
#   '1,832,479\n(+9,160)',
#   '148,617\n(+595)',
#   '179,293\n(+218)',
#   '151,901\n(+395)',
#   '3,968,405\n(+23,239)',
#   '3,764,651\n(+7,209)',
#   '72,679\n(+1,136)',
#   '4,277,395\n(+8,606)',
#   '136,294\n(+473)',
#   '36,347',
#   '2,229,846',
#   '1,292,700',
#   '105,755',
#   '2,878,840',
#   '1,409,607\n(+771)',
#   '526,737\n(+86)',
#   '475,403',
#   '106,847\n(+395)',
#   '2,030,611\n(+986)',
#   '37,748\n(+70)',
#   '701,019',
#   '72,577\n(+70)',
#   '95,059\n(+146)',
#   '6,889\n(+4)',
#   '622,640',
#   '262,038\n(+1,298)',
#   '42,137',
#   '80,328',
#   '48,047\n(+3)',
#   '30,366\n(+14)',
#   '5,469',
#   '14,080',
#   '241,820\n(+2,131)',
#   '13,469',
#   '14,385\n(+4)',
#   '1,080,282',
#   '34,914\n(+46)',
#   '1,522,223\n(+5,205)',
#   '410,523\n(+943)',
#   '130,631',
#   '280,854\n(+347)',
#   '446,633\n(+192)',
#   '25,158\n(+40)',
#   '1,679,542',
#   '42,437',
#   '44,124\n(+678)',
#   '4,947\n(+1)',
#   '14,867\n(+15)',
#   '42,195\n(+416)',
#   '23,535\n(+85)',
#   '31,435\n(+622)',
#   '8,140',
#   '5,242\n(+121)',
#   '385,428\n(+2,478)',
#   '422,811\n(+764)',
#   '1,079,640\n(+225)',
#   '17,371',
#   '169,365\n(+1,561)',
#   '10,786\n(+16)',
#   '317,645\n(+858)',
#   '1,666,192\n(+110)',
#   '418,548\n(+206)',
#   '747,000\n(+520)',
#   '865,806\n(+756)',
#   '335,521',
#   '1,084,636',
#   '254,194\n(+319)',
#   '613,993',
#   '807,684\n(+54)',
#   '13,308',
#   '411,153',
#   '649,670',
#   '17,013',
#   '715,841',
#   '839,990\n(+123)',
#   '701,994',
#   '13,731\n(+10)',
#   '4,879\n(+63)',
#   '11,889',
#   '2,067\n(+13)',
#   '407,721\n(+1,501)',
#   '421,152\n(+120)',
#   '191,038',
#   '543,551\n(+46)',
#   '7,696',
#   '116,546\n(+931)',
#   '77,484\n(+384)',
#   '62,430',
#   '291,801',
#   '94,379',
#   '12,298',
#   '391,326',
#   '129,545\n(+212)',
#   '250,572',
#   '312,811\n(+138)',
#   '354,095\n(+3,465)',
#   '3,109\n(+114)',
#   '269,321\n(+273)',
#   '7,129\n(+28)',
#   '2,720',
#   '20,365\n(+29)',
#   '394,241\n(+514)',
#   '340,967\n(+1,935)',
#   '359,184',
#   '256,187\n(+47)',
#   '360,055\n(+914)',
#   '5,421\n(+59)',
#   '356,382\n(+1,517)',
#   '204,860\n(+46)',
#   '98,050\n(+2,231)',
#   '224,330\n(+77)',
#   '49,712\n(+44)',
#   '220,930',
#   '132,491\n(+1)',
#   '278,407',
#   '75,766\n(+1,084)',
#   '6,045\n(+21)',
#   '65,808\n(+2,561)',
#   '24,864',
#   '11,107\n(+26)',
#   '155,627',
#   '257,001',
#   '3,825',
#   '136,850',
#   '107,247',
#   '263,295\n(+403)',
#   '8,708\n(+10)',
#   '30,767\n(+148)',
#   '130,818',
#   '8,728',
#   '1,701',
#   '73,710\n(+67)',
#   '18,831\n(+18)',
#   '11,591\n(+4)',
#   '2,090',
#   '28,441',
#   '3,912\n(+4)',
#   '19,144\n(+48)',
#   '1,939\n(+15)',
#   '20',
#   '53',
#   '100,092\n(+17)',
#   '70,535\n(+19)',
#   '10',
#   '20,141\n(+116)',
#   '32,039\n(+37)',
#   '72,149\n(+253)',
#   '30,590',
#   '255',
#   '16,752',
#   '13,039\n(+35)',
#   '12,364\n(+69)',
#   '12,178',
#   '6,630\n(+3)',
#   '4',
#   '26,647\n(+197)',
#   '4,045\n(+2)',
#   '129',
#   '18,972\n(+9)',
#   '19,389',
#   '2,362',
#   '3',
#   '5,218\n(+2)',
#   '12,319\n(+1)',
#   '1',
#   '161',
#   '2,196\n(+1)',
#   '11,112\n(+4)',
#   '14,620\n(+497)',
#   '1,263',
#   '1,599',
#   '13,864',
#   '191',
#   '609\n(+1)',
#   '2,504',
#   '4',
#   '50\n(+1)',
#   '350\n(+9)',
#   '768\n(+2)',
#   '2,575\n(+5)',
#   '2,549\n(+1)',
#   '2,424',
#   '2,133',
#   '3,028\n(+2)',
#   '5,090',
#   '4,321',
#   '248',
#   '1,633\n(+1)',
#   '109',
#   '1,005',
#   '2',
#   '26',
#   '20',
#   '63',
#   '27',
#   '445',
#   '9'],
#  ['512\n(-10)',
#   '662,521\n(-18,767)',
#   '5,034,868\n(-42,709)',
#   '147,728',
#   '33,452\n(-568)',
#   '1,178,597\n(-27,175)',
#   '1,377\n(-155)',
#   '57,196',
#   '326,070',
#   '273,052\n(-1,574)',
#   '22,248',
#   '15,530\n(-433)',
#   '55,847',
#   '55,846\n(+30)',
#   '8,008\n(+45)',
#   '9,109\n(+117)',
#   '88,626\n(+150)',
#   '262,290',
#   '31,492\n(-2,584)',
#   '35,836\n(+1,977)',
#   '208,530\n(+8,451)',
#   '80,626\n(-9,361)',
#   '76,853\n(-10,857)',
#   '305',
#   '117,004\n(-110)',
#   '11,599\n(+445)',
#   '52,867\n(-48)',
#   '6,078\n(-156)',
#   '181,876\n(+3,805)',
#   '123,928\n(-8,657)',
#   '22,205\n(+854)',
#   '277,070\n(-12,463)',
#   '37,831\n(+212)',
#   '3,548',
#   '25,674',
#   '70,911',
#   '36,391',
#   '153,363',
#   '11,032\n(-728)',
#   '3,595\n(-137)',
#   '10,584',
#   '3,581\n(+10)',
#   'N/A',
#   '5,098\n(-45)',
#   '62,918',
#   '1,488\n(-122)',
#   '1,260\n(+21)',
#   '1,576\n(-1)',
#   '53,940',
#   '16,708\n(-141)',
#   '765',
#   '853',
#   '252\n(-39)',
#   '184\n(+14)',
#   '98',
#   '5,977\n(-6,401)',
#   '37,798\n(+2,079)',
#   '9',
#   '3,825\n(+1)',
#   '2,684',
#   '852\n(+23)',
#   '38,470\n(-1,332)',
#   '20,147\n(-148)',
#   '18,490',
#   '17,419\n(-454)',
#   '9,821\n(+181)',
#   '1,563\n(+28)',
#   'N/A',
#   '365',
#   '4,899\n(-103)',
#   '5\n(+1)',
#   '6,888\n(-39)',
#   '3,310\n(+387)',
#   '1,085\n(+53)',
#   '4,343\n(+616)',
#   '58',
#   '4,461\n(+121)',
#   '34,658\n(-1,292)',
#   '65,678\n(-1,133)',
#   '37,925\n(+220)',
#   '4,319',
#   '8,420\n(+263)',
#   '157\n(+16)',
#   '54,238\n(-620)',
#   '2,427\n(-213)',
#   '6,111\n(-683)',
#   '6,498\n(-135)',
#   '28,657\n(+360)',
#   '959',
#   'N/A',
#   '155,560\n(+179)',
#   '19,246',
#   '41,784\n(-313)',
#   '0',
#   '4,075',
#   '2,625',
#   '444',
#   '2,849',
#   '501\n(+123)',
#   '14,625\n(-3)',
#   '245\n(+7)',
#   '1,528\n(+58)',
#   '63\n(-2)',
#   '110\n(+7)',
#   '49,332\n(-1,296)',
#   '9,966\n(-260)',
#   '11,410',
#   '5,333\n(-732)',
#   '3,283',
#   '8,669\n(+401)',
#   '3,545\n(+124)',
#   '325\n(-29)',
#   '4,518',
#   '47,412',
#   '926',
#   '875',
#   '39,803\n(+212)',
#   '27,660',
#   '2,945\n(+63)',
#   '71,340\n(-2,689)',
#   '841\n(+46)',
#   '11,054\n(-108)',
#   '172\n(+28)',
#   '23',
#   '446\n(+4)',
#   '10,521\n(+30)',
#   '17,797\n(+520)',
#   '535',
#   '798\n(+5)',
#   '8,639\n(+255)',
#   '505\n(-20)',
#   '24,195\n(-1,905)',
#   '14,972\n(-354)',
#   '33,237\n(+1,333)',
#   '3,646\n(+4)',
#   '19,885\n(-130)',
#   '1,912',
#   '107\n(-11)',
#   '8,407',
#   '14,103\n(+261)',
#   '27\n(+11)',
#   '5,123\n(+1,357)',
#   '442',
#   '4,333\n(+26)',
#   '273',
#   '1,562',
#   '198',
#   '1,633',
#   '-34',
#   '7,071\n(-605)',
#   '99\n(+10)',
#   '8,148\n(-126)',
#   '2,854',
#   '1,042',
#   '418',
#   '1,253\n(-27)',
#   '115\n(-4)',
#   '5',
#   '1,551',
#   '1,888',
#   '21\n(+4)',
#   '1,520\n(-56)',
#   '253\n(+6)',
#   '0',
#   '2',
#   '298\n(-5)',
#   '258\n(-146)',
#   '1',
#   '4,250\n(+8)',
#   '665\n(-66)',
#   '4,795\n(-516)',
#   '23',
#   '8',
#   '14,273',
#   '142\n(+17)',
#   '799\n(-25)',
#   '11,982',
#   '24\n(+3)',
#   '0',
#   '16,510\n(+192)',
#   '10',
#   '71',
#   '25\n(-9)',
#   '16,251',
#   '11',
#   '0',
#   '73\n(-2)',
#   '33',
#   '0',
#   '0',
#   '248',
#   '30\n(+2)',
#   '1,238\n(-325)',
#   '0',
#   '4',
#   '72',
#   '2',
#   '20\n(+1)',
#   '10',
#   '0',
#   '10\n(+1)',
#   '273\n(+8)',
#   '12\n(+2)',
#   '56\n(-5)',
#   '35\n(-6)',
#   '17',
#   '722',
#   '12',
#   '1',
#   '16',
#   '38',
#   '14\n(-2)',
#   '0',
#   '542',
#   '0',
#   '1',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'],
#  ['4,636',
#   '389,302\n(+474)',
#   '617,463\n(+297)',
#   '54,956',
#   '22,034\n(+27)',
#   '502,817\n(+899)',
#   '2,118\n(+1)',
#   '13,626',
#   '129,801',
#   '231,244\n(+57)',
#   '14,439',
#   '4,286\n(+3)',
#   '23,749',
#   '15,898\n(+39)',
#   '69\n(+2)',
#   '879',
#   '49,236\n(+51)',
#   '83,101',
#   '91,007\n(+37)',
#   '1,693\n(+35)',
#   '127,981\n(+5)',
#   '110,778\n(+40)',
#   '127,291\n(+21)',
#   '21',
#   '58,795\n(+93)',
#   '3,265\n(+3)',
#   '3,461\n(+5)',
#   '2,006\n(+2)',
#   '100,582\n(+648)',
#   '80,689\n(+37)',
#   '680\n(+20)',
#   '89,490\n(+447)',
#   '3,641\n(+10)',
#   '2,737',
#   '52,032',
#   '16,910',
#   '4,293',
#   '74,829',
#   '26,084\n(+8)',
#   '9,244\n(+6)',
#   '7,691',
#   '720\n(+2)',
#   '190,645\n(+220)',
#   '868\n(+9)',
#   '4,477',
#   '848',
#   '794\n(+1)',
#   '1,355',
#   '8,772',
#   '2,973\n(+15)',
#   '903',
#   '1,313',
#   '308',
#   '910',
#   '193',
#   '569',
#   '2,633\n(+52)',
#   '167',
#   '524',
#   '32,391',
#   '1,171\n(+3)',
#   '31,645\n(+132)',
#   '4,249\n(+7)',
#   '1,691',
#   '8,735\n(+41)',
#   '21,304\n(+11)',
#   '1,848\n(+3)',
#   '17,727',
#   '1,158',
#   '459\n(+18)',
#   '174',
#   '775',
#   '1,685\n(+13)',
#   '168',
#   '388\n(+6)',
#   '103',
#   '8',
#   '14,118\n(+80)',
#   '16,174\n(+42)',
#   '25,141\n(+5)',
#   '385',
#   '1,170\n(+11)',
#   '115',
#   '3,758\n(+2)',
#   '30,283\n(+3)',
#   '12,559\n(+17)',
#   '9,671\n(+9)',
#   '17,068\n(+3)',
#   '4,963',
#   '14,537',
#   '6,772\n(+6)',
#   '1,763',
#   '29,963\n(+4)',
#   '90',
#   '3,053',
#   '10,680',
#   '173',
#   '7,004',
#   '6,428',
#   '10,875\n(+3)',
#   '128',
#   '82',
#   '210',
#   '3',
#   '11,743\n(+110)',
#   '18,000\n(+10)',
#   '3,178',
#   '7,825\n(+3)',
#   '188',
#   '1,945\n(+8)',
#   '2,336\n(+4)',
#   '35\n(+1)',
#   '2,531',
#   '967',
#   '161',
#   '12,496',
#   '790',
#   '2,741',
#   '3,554\n(+3)',
#   '4,530\n(+57)',
#   '99\n(+4)',
#   '4,979\n(+38)',
#   '98',
#   '26',
#   '481',
#   '6,477\n(+2)',
#   '1,877\n(+7)',
#   '8,182',
#   '6,173\n(+3)',
#   '5,199\n(+24)',
#   '19',
#   '5,316\n(+45)',
#   '9,643\n(+13)',
#   '459\n(+12)',
#   '4,502\n(+3)',
#   '1,034\n(+1)',
#   '583',
#   '2,455\n(+1)',
#   '4,367',
#   '1,179\n(+15)',
#   '181',
#   '1,069\n(+129)',
#   '158',
#   '329',
#   '5,477',
#   '4,415',
#   '69',
#   '2,496',
#   '2,256',
#   '1,311\n(+5)',
#   '120',
#   '747\n(+10)',
#   '1,268',
#   '19',
#   '18',
#   '374',
#   '677',
#   '155',
#   '7',
#   '220',
#   '146',
#   '449\n(+2)',
#   '1',
#   '0',
#   '0',
#   '1,605',
#   '818',
#   '1',
#   '467\n(+7)',
#   '283',
#   '206',
#   '420',
#   '3',
#   '229',
#   '329\n(+1)',
#   '243\n(+2)',
#   '98',
#   '30',
#   '1',
#   '142\n(+5)',
#   '47',
#   '0',
#   '142',
#   '174',
#   '37',
#   '0',
#   '80',
#   '125',
#   '0',
#   '1',
#   '12',
#   '107',
#   '59\n(+4)',
#   '42',
#   '29',
#   '127',
#   '0',
#   '2',
#   '33',
#   '0',
#   '0',
#   '2\n(+1)',
#   '1',
#   '32',
#   '33',
#   '18',
#   '12',
#   '59',
#   '90',
#   '94',
#   '1',
#   '17',
#   '0',
#   '1',
#   '0',
#   '0',
#   '1',
#   '0',
#   '0',
#   '7',
#   '2'],
#  ['86,481\n(+35)',
#   '28,926,038\n(+30,862)',
#   '28,767,507\n(+56,191)',
#   '1,801,761',
#   '894,352\n(+1,204)',
#   '16,288,392\n(+68,154)',
#   '163,797\n(+240)',
#   '785,482',
#   '4,878,333',
#   '1,974,255\n(+2,785)',
#   '749,282',
#   '255,502\n(+554)',
#   '1,284,643',
#   '206,053\n(+440)',
#   '5,453',
#   '27,938',
#   '5,237,731\n(+5,093)',
#   '2,760,229',
#   '3,608,100\n(+2,900)',
#   '187,836\n(+2,047)',
#   '4,303,996\n(+2,011)',
#   '5,566,394\n(+9,808)',
#   '4,049,316\n(+11,320)',
#   '183',
#   '1,656,680\n(+9,177)',
#   '133,753\n(+147)',
#   '122,965\n(+261)',
#   '143,817\n(+549)',
#   '3,685,947\n(+18,786)',
#   '3,560,034\n(+15,829)',
#   '49,794\n(+262)',
#   '3,910,835\n(+20,622)',
#   '94,822\n(+251)',
#   '30,062',
#   '2,152,140',
#   '1,204,879',
#   '65,071',
#   '2,650,648',
#   '1,372,491\n(+1,491)',
#   '513,898\n(+217)',
#   '457,128',
#   '102,546\n(+383)',
#   'N/A',
#   '31,782\n(+106)',
#   '633,624',
#   '70,241\n(+192)',
#   '93,005\n(+124)',
#   '3,958\n(+5)',
#   '559,928',
#   '242,357\n(+1,424)',
#   '40,469',
#   '78,162',
#   '47,487\n(+42)',
#   '29,272',
#   '5,178',
#   '7,534\n(+6,401)',
#   '201,389',
#   '13,293',
#   '10,036\n(+3)',
#   '1,045,207',
#   '32,891\n(+20)',
#   '1,452,108\n(+6,405)',
#   '386,127\n(+1,084)',
#   '110,450',
#   '254,700\n(+760)',
#   '415,508',
#   '21,747\n(+9)',
#   'N/A',
#   '40,914',
#   '38,766\n(+763)',
#   '4,768',
#   '7,204\n(+54)',
#   '37,200\n(+16)',
#   '22,282\n(+32)',
#   '26,704',
#   '7,979',
#   '773',
#   '336,652\n(+3,690)',
#   '340,959\n(+1,855)',
#   '1,016,574',
#   '12,667',
#   '159,775\n(+1,287)',
#   '10,514',
#   '259,649\n(+1,476)',
#   '1,633,482\n(+320)',
#   '399,878\n(+872)',
#   '730,831\n(+646)',
#   '820,081\n(+393)',
#   '329,599',
#   'N/A',
#   '91,862\n(+134)',
#   '592,984',
#   '735,937\n(+363)',
#   '13,218',
#   '404,025',
#   '636,365',
#   '16,396',
#   '705,988',
#   '833,061',
#   '676,494',
#   '13,358\n(+3)',
#   '3,269\n(+5)',
#   '11,616\n(+2)',
#   '1,954\n(+6)',
#   '346,646\n(+2,687)',
#   '393,186\n(+370)',
#   '176,450',
#   '530,393\n(+775)',
#   '4,225',
#   '105,932\n(+522)',
#   '71,603\n(+256)',
#   '62,070\n(+28)',
#   '284,752',
#   '46,000',
#   '11,211',
#   '377,955',
#   '88,952',
#   '220,171',
#   '306,312\n(+72)',
#   '278,225\n(+6,097)',
#   '2,169\n(+64)',
#   '253,288\n(+343)',
#   '6,859',
#   '2,671',
#   '19,438\n(+25)',
#   '377,243\n(+482)',
#   '321,293\n(+1,408)',
#   '350,467',
#   '249,216\n(+39)',
#   '346,217\n(+635)',
#   '4,897\n(+79)',
#   '326,871\n(+3,377)',
#   '180,245\n(+387)',
#   '64,354\n(+886)',
#   '216,182\n(+70)',
#   '28,793\n(+173)',
#   '218,435',
#   '129,929\n(+11)',
#   '265,633',
#   '60,484\n(+808)',
#   '5,837\n(+10)',
#   '59,616\n(+1,075)',
#   '24,264',
#   '6,445',
#   '149,877',
#   '251,024',
#   '3,558',
#   '132,721',
#   '105,025',
#   '254,913\n(+1,003)',
#   '8,489',
#   '21,872\n(+264)',
#   '126,696',
#   '7,667',
#   '1,265',
#   '72,083\n(+94)',
#   '18,039\n(+22)',
#   '11,431\n(+4)',
#   '532',
#   '26,333',
#   '3,745',
#   '17,175\n(+102)',
#   '1,685\n(+9)',
#   '20',
#   '51',
#   '98,189\n(+22)',
#   '69,459\n(+165)',
#   '8',
#   '15,424\n(+101)',
#   '31,091\n(+103)',
#   '67,148\n(+769)',
#   '30,147',
#   '244',
#   '2,250',
#   '12,568\n(+17)',
#   '11,322\n(+92)',
#   '98',
#   '6,576',
#   '3',
#   '9,995',
#   '3,988\n(+2)',
#   '58',
#   '18,805\n(+18)',
#   '2,964',
#   '2,314',
#   '3',
#   '5,065\n(+4)',
#   '12,161\n(+1)',
#   '1',
#   '160',
#   '1,936\n(+1)',
#   '10,975\n(+2)',
#   '13,323\n(+818)',
#   '1,221',
#   '1,566',
#   '13,665',
#   '189',
#   '587',
#   '2,461',
#   '4',
#   '40',
#   '75',
#   '755',
#   '2,487\n(+10)',
#   '2,481\n(+7)',
#   '2,389',
#   '1,399',
#   '2,957\n(+2)',
#   '4,999',
#   '4,211',
#   '209',
#   '1,602\n(+3)',
#   '109',
#   '462',
#   '2',
#   '25',
#   '19',
#   '63',
#   '27',
#   '438',
#   '7'],
#  ['5.1',
#   '1.3',
#   '1.8',
#   '2.7',
#   '2.3',
#   '2.8',
#   '1.3',
#   '1.6',
#   '2.4',
#   '9.3',
#   '1.8',
#   '1.6',
#   '1.7',
#   '5.7',
#   '0.5',
#   '2.3',
#   '0.9',
#   '2.7',
#   '2.4',
#   '0.8',
#   '2.8',
#   '1.9',
#   '3.0',
#   '4.1',
#   '3.2',
#   '2.2',
#   '1.9',
#   '1.3',
#   '2.5',
#   '2.1',
#   '0.9',
#   '2.1',
#   '2.7',
#   '7.5',
#   '2.3',
#   '1.3',
#   '4.1',
#   '2.6',
#   '1.9',
#   '1.8',
#   '1.6',
#   '0.7',
#   '9.4',
#   '2.3',
#   '0.6',
#   '1.2',
#   '0.8',
#   '19.7',
#   '1.4',
#   '1.1',
#   '2.1',
#   '1.6',
#   '0.6',
#   '3.0',
#   '3.5',
#   '4.0',
#   '1.1',
#   '1.2',
#   '3.6',
#   '3.0',
#   '3.4',
#   '2.1',
#   '1.0',
#   '1.3',
#   '3.1',
#   '4.8',
#   '7.3',
#   '1.1',
#   '2.7',
#   '1.0',
#   '3.5',
#   '5.2',
#   '4.0',
#   '0.7',
#   '1.2',
#   '1.3',
#   '0.2',
#   '3.7',
#   '3.8',
#   '2.3',
#   '2.2',
#   '0.7',
#   '1.1',
#   '1.2',
#   '1.8',
#   '3.0',
#   '1.3',
#   '2.0',
#   '1.5',
#   '1.3',
#   '2.7',
#   '0.3',
#   '3.7',
#   '0.7',
#   '0.7',
#   '1.6',
#   '1.0',
#   '1.0',
#   '0.8',
#   '1.5',
#   '0.9',
#   '1.7',
#   '1.8',
#   '0.1',
#   '2.9',
#   '4.3',
#   '1.7',
#   '1.4',
#   '2.4',
#   '1.7',
#   '3.0',
#   '0.1',
#   '0.9',
#   '1.0',
#   '1.3',
#   '3.2',
#   '0.6',
#   '1.1',
#   '1.1',
#   '1.3',
#   '3.2',
#   '1.8',
#   '1.4',
#   '1.0',
#   '2.4',
#   '1.6',
#   '0.6',
#   '2.3',
#   '2.4',
#   '1.4',
#   '0.4',
#   '1.5',
#   '4.7',
#   '0.5',
#   '2.0',
#   '2.1',
#   '0.3',
#   '1.9',
#   '1.6',
#   '1.6',
#   '3.0',
#   '1.6',
#   '0.6',
#   '3.0',
#   '3.5',
#   '1.7',
#   '1.8',
#   '1.8',
#   '2.1',
#   '0.5',
#   '1.4',
#   '2.4',
#   '1.0',
#   '0.2',
#   '1.1',
#   '0.5',
#   '3.6',
#   '1.3',
#   '0.3',
#   '0.8',
#   '3.7',
#   '2.3',
#   '0.1',
#   '-',
#   '-',
#   '1.6',
#   '1.2',
#   '10',
#   '2.3',
#   '0.9',
#   '0.3',
#   '1.4',
#   '1.2',
#   '1.4',
#   '2.5',
#   '2.0',
#   '0.8',
#   '0.5',
#   '25',
#   '0.5',
#   '1.2',
#   '-',
#   '0.7',
#   '0.9',
#   '1.6',
#   '-',
#   '1.5',
#   '1.0',
#   '-',
#   '0.6',
#   '0.5',
#   '1.0',
#   '0.4',
#   '3.3',
#   '1.8',
#   '0.9',
#   '-',
#   '0.3',
#   '1.3',
#   '-',
#   '-',
#   '0.6',
#   '0.1',
#   '1.2',
#   '1.3',
#   '0.7',
#   '0.6',
#   '1.9',
#   '1.8',
#   '2.2',
#   '0.4',
#   '1.0',
#   '-',
#   '0.1',
#   '-',
#   '-',
#   '5',
#   '-',
#   '-',
#   '1.6',
#   '22.2'],
#  ['94.4',
#   '96.5',
#   '83.6',
#   '89.9',
#   '94.2',
#   '90.6',
#   '97.9',
#   '91.7',
#   '91.5',
#   '79.7',
#   '95.3',
#   '92.8',
#   '94.2',
#   '74.2',
#   '40.3',
#   '73.7',
#   '97.4',
#   '88.9',
#   '96.7',
#   '83.3',
#   '92.7',
#   '96.7',
#   '95.2',
#   '36.0',
#   '90.4',
#   '90.0',
#   '68.6',
#   '94.7',
#   '92.9',
#   '94.6',
#   '68.5',
#   '91.4',
#   '69.6',
#   '82.7',
#   '96.5',
#   '93.2',
#   '61.5',
#   '92.1',
#   '97.4',
#   '97.6',
#   '96.2',
#   '96.0',
#   'N/A',
#   '84.2',
#   '90.4',
#   '96.8',
#   '97.8',
#   '57.5',
#   '89.9',
#   '92.5',
#   '96.0',
#   '97.3',
#   '98.8',
#   '96.4',
#   '94.7',
#   '53.5',
#   '83.3',
#   '98.7',
#   '69.8',
#   '96.8',
#   '94.2',
#   '95.4',
#   '94.1',
#   '84.6',
#   '90.7',
#   '93.0',
#   '86.4',
#   'N/A',
#   '96.4',
#   '87.9',
#   '96.4',
#   '48.5',
#   '88.2',
#   '94.7',
#   '84.9',
#   '98.0',
#   '14.7',
#   '87.3',
#   '80.6',
#   '94.2',
#   '72.9',
#   '94.3',
#   '97.5',
#   '81.7',
#   '98.0',
#   '95.5',
#   '97.8',
#   '94.7',
#   '98.2',
#   'N/A',
#   '36.1',
#   '96.6',
#   '91.1',
#   '99.3',
#   '98.3',
#   '98.0',
#   '96.4',
#   '98.6',
#   '99.2',
#   '96.4',
#   '97.3',
#   '67.0',
#   '97.7',
#   '94.5',
#   '85.0',
#   '93.4',
#   '92.4',
#   '97.6',
#   '54.9',
#   '90.9',
#   '92.4',
#   '99.4',
#   '97.6',
#   '48.7',
#   '91.2',
#   '96.6',
#   '68.7',
#   '87.9',
#   '97.9',
#   '78.6',
#   '69.8',
#   '94.0',
#   '96.2',
#   '98.2',
#   '95.4',
#   '95.7',
#   '94.2',
#   '97.6',
#   '97.3',
#   '96.2',
#   '90.3',
#   '91.7',
#   '88.0',
#   '65.6',
#   '96.4',
#   '57.9',
#   '98.9',
#   '98.1',
#   '95.4',
#   '79.8',
#   '96.6',
#   '90.6',
#   '97.6',
#   '58.0',
#   '96.3',
#   '97.7',
#   '93.0',
#   '97.0',
#   '97.9',
#   '96.8',
#   '97.5',
#   '71.1',
#   '96.8',
#   '87.8',
#   '74.4',
#   '97.8',
#   '95.8',
#   '98.6',
#   '25.5',
#   '92.6',
#   '95.7',
#   '89.7',
#   '86.9',
#   '100',
#   '96.2',
#   '98.1',
#   '98.5',
#   '80',
#   '76.6',
#   '97.0',
#   '93.1',
#   '98.6',
#   '95.7',
#   '13.4',
#   '96.4',
#   '91.6',
#   '0.8',
#   '99.2',
#   '75',
#   '37.5',
#   '98.6',
#   '45.0',
#   '99.1',
#   '15.3',
#   '98.0',
#   '100',
#   '97.1',
#   '98.7',
#   '100',
#   '99.4',
#   '88.2',
#   '98.8',
#   '91.1',
#   '96.7',
#   '97.9',
#   '98.6',
#   '99.0',
#   '96.4',
#   '98.3',
#   '100',
#   '80',
#   '21.4',
#   '98.3',
#   '96.6',
#   '97.3',
#   '98.6',
#   '65.6',
#   '97.7',
#   '98.2',
#   '97.5',
#   '84.3',
#   '98.1',
#   '100',
#   '46.0',
#   '100',
#   '96.2',
#   '95',
#   '100',
#   '100',
#   '98.4',
#   '77.8'],
#  ['64',
#   '21,723',
#   '103,987',
#   '7,328',
#   '4,300',
#   '84,540',
#   '812',
#   '5,200',
#   '36,552',
#   '19,224',
#   '6,214',
#   '2,395',
#   '12,450',
#   '2,715',
#   '139',
#   '423',
#   '63,738',
#   '36,975',
#   '44,526',
#   '3,229',
#   '68,357',
#   '88,210',
#   '70,350',
#   '9',
#   '30,897',
#   '2,731',
#   '3,334',
#   '2,963',
#   '77,991',
#   '80,519',
#   '1,589',
#   '94,641',
#   '3,108',
#   '829',
#   '50,987',
#   '32,139',
#   '2,717',
#   '76,066',
#   '37,348',
#   '14,271',
#   '13,656',
#   '3,192',
#   '61,586',
#   '1,149',
#   '21,659',
#   '2,322',
#   '3,059',
#   '231',
#   '21,370',
#   '9,215',
#   '1,522',
#   '3,026',
#   '1,821',
#   '1,191',
#   '226',
#   '591',
#   '11,293',
#   '644',
#   '710',
#   '56,154',
#   '1,825',
#   '79,630',
#   '21,863',
#   '7,106',
#   '15,677',
#   '25,315',
#   '1,438',
#   '98,019',
#   '2,534',
#   '2,639',
#   '301',
#   '935',
#   '2,839',
#   '1,792',
#   '2,427',
#   '671',
#   '441',
#   '32,612',
#   '36,221',
#   '93,156',
#   '1,523',
#   '14,953',
#   '964',
#   '29,282',
#   '155,588',
#   '40,156',
#   '73,213',
#   '84,910',
#   '33,092',
#   '107,398',
#   '25,664',
#   '62,080',
#   '83,608',
#   '1,395',
#   '43,511',
#   '72,134',
#   '1,902',
#   '81,929',
#   '97,047',
#   '81,112',
#   '1,659',
#   '612',
#   '1,586',
#   '284',
#   '57,164',
#   '60,611',
#   '27,802',
#   '79,636',
#   '1,162',
#   '17,864',
#   '11,946',
#   '10,671',
#   '50,378',
#   '17,034',
#   '2,229',
#   '71,676',
#   '23,896',
#   '49,068',
#   '61,318',
#   '69,511',
#   '615',
#   '54,543',
#   '1,476',
#   '564',
#   '4,380',
#   '91,370',
#   '79,841',
#   '87,493',
#   '63,508',
#   '90,258',
#   '1,529',
#   '102,593',
#   '62,442',
#   '29,909',
#   '75,704',
#   '16,788',
#   '76,684',
#   '46,039',
#   '102,269',
#   '29,819',
#   '2,501',
#   '27,984',
#   '11,171',
#   '5,185',
#   '74,700',
#   '123,621',
#   '1,944',
#   '72,553',
#   '59,237',
#   '154,736',
#   '6,207',
#   '21,984',
#   '98,616',
#   '6,620',
#   '1,338',
#   '61,051',
#   '16,231',
#   '11,732',
#   '2,331',
#   '31,767',
#   '4,499',
#   '24,339',
#   '2,513',
#   '29',
#   '82',
#   '159,365',
#   '112,680',
#   '17',
#   '34,333',
#   '57,625',
#   '133,475',
#   '69,280',
#   '583',
#   '41,867',
#   '32,792',
#   '31,441',
#   '32,452',
#   '19,429',
#   '13',
#   '89,215',
#   '14,076',
#   '452',
#   '67,538',
#   '71,070',
#   '10,778',
#   '15',
#   '28,416',
#   '75,073',
#   '9',
#   '1,431',
#   '19,794',
#   '104,078',
#   '148,657',
#   '12,897',
#   '18,804',
#   '179,434',
#   '2,653',
#   '9,266',
#   '40,207',
#   '68',
#   '881',
#   '6,579',
#   '15,717',
#   '60,057',
#   '64,956',
#   '62,608',
#   '55,165',
#   '79,417',
#   '150,010',
#   '128,254',
#   '8,203',
#   '62,274',
#   '7,265',
#   '101,752',
#   '329',
#   '4,487',
#   '4,006',
#   '18,103',
#   '33,708',
#   '-',
#   '-'],
#  ['1,439,323,776',
#   '1,380,004,385',
#   '331,002,651',
#   '273,523,615',
#   '220,892,340',
#   '212,559,417',
#   '206,139,589',
#   '164,689,383',
#   '145,934,462',
#   '128,932,753',
#   '126,476,461',
#   '114,963,588',
#   '109,581,078',
#   '102,334,404',
#   '97,338,579',
#   '89,561,403',
#   '84,339,067',
#   '83,992,949',
#   '83,783,942',
#   '69,799,978',
#   '67,886,011',
#   '65,273,511',
#   '60,461,826',
#   '59,734,218',
#   '59,308,690',
#   '54,409,800',
#   '53,771,296',
#   '51,269,185',
#   '50,882,891',
#   '46,754,778',
#   '45,741,007',
#   '45,195,774',
#   '43,851,044',
#   '43,849,260',
#   '43,733,762',
#   '40,222,493',
#   '38,928,346',
#   '37,846,611',
#   '37,742,154',
#   '36,910,560',
#   '34,813,871',
#   '33,469,203',
#   '32,971,854',
#   '32,866,272',
#   '32,365,999',
#   '31,255,435',
#   '31,072,940',
#   '29,825,964',
#   '29,136,808',
#   '28,435,940',
#   '27,691,018',
#   '26,545,863',
#   '26,378,274',
#   '25,499,884',
#   '24,206,644',
#   '23,816,775',
#   '21,413,249',
#   '20,903,273',
#   '20,250,833',
#   '19,237,691',
#   '19,129,952',
#   '19,116,201',
#   '18,776,707',
#   '18,383,955',
#   '17,915,568',
#   '17,643,054',
#   '17,500,658',
#   '17,134,872',
#   '16,743,927',
#   '16,718,965',
#   '16,425,864',
#   '15,893,222',
#   '14,862,924',
#   '13,132,795',
#   '12,952,218',
#   '12,123,200',
#   '11,890,784',
#   '11,818,619',
#   '11,673,021',
#   '11,589,623',
#   '11,402,528',
#   '11,326,616',
#   '11,193,725',
#   '10,847,910',
#   '10,708,981',
#   '10,423,054',
#   '10,203,134',
#   '10,196,709',
#   '10,139,177',
#   '10,099,265',
#   '9,904,607',
#   '9,890,402',
#   '9,660,351',
#   '9,537,645',
#   '9,449,323',
#   '9,006,398',
#   '8,947,024',
#   '8,737,371',
#   '8,655,535',
#   '8,654,622',
#   '8,278,724',
#   '7,976,983',
#   '7,496,981',
#   '7,275,560',
#   '7,132,538',
#   '6,948,445',
#   '6,871,292',
#   '6,825,445',
#   '6,624,554',
#   '6,524,195',
#   '6,486,205',
#   '5,850,342',
#   '5,792,202',
#   '5,540,720',
#   '5,518,087',
#   '5,459,642',
#   '5,421,241',
#   '5,106,626',
#   '5,101,414',
#   '5,094,118',
#   '5,057,681',
#   '4,937,786',
#   '4,829,767',
#   '4,822,233',
#   '4,649,658',
#   '4,314,767',
#   '4,270,571',
#   '4,105,267',
#   '4,033,963',
#   '3,989,167',
#   '3,546,421',
#   '3,473,730',
#   '3,280,819',
#   '3,278,290',
#   '2,963,243',
#   '2,961,167',
#   '2,881,053',
#   '2,877,797',
#   '2,722,289',
#   '2,540,905',
#   '2,416,668',
#   '2,351,627',
#   '2,225,734',
#   '2,142,249',
#   '2,083,374',
#   '2,078,938',
#   '1,968,001',
#   '1,886,198',
#   '1,810,463',
#   '1,701,575',
#   '1,402,985',
#   '1,399,488',
#   '1,326,535',
#   '1,318,445',
#   '1,271,768',
#   '1,207,359',
#   '1,160,164',
#   '988,000',
#   '896,445',
#   '895,312',
#   '869,601',
#   '786,552',
#   '771,608',
#   '686,884',
#   '649,335',
#   '628,066',
#   '625,978',
#   '597,339',
#   '586,632',
#   '555,987',
#   '540,544',
#   '441,543',
#   '437,479',
#   '400,124',
#   '397,628',
#   '393,244',
#   '375,265',
#   '341,243',
#   '307,145',
#   '298,682',
#   '287,375',
#   '285,498',
#   '280,908',
#   '272,815',
#   '219,159',
#   '198,414',
#   '183,627',
#   '164,093',
#   '115,023',
#   '112,523',
#   '110,940',
#   '106,766',
#   '98,347',
#   '97,929',
#   '85,033',
#   '77,265',
#   '71,986',
#   '65,722',
#   '62,278',
#   '59,190',
#   '56,770',
#   '53,199',
#   '48,863',
#   '42,876',
#   '39,242',
#   '38,717',
#   '38,666',
#   '38,128',
#   '33,931',
#   '33,691',
#   '30,231',
#   '26,223',
#   '15,003',
#   '9,877',
#   '6,077',
#   '5,794',
#   '4,992',
#   '3,480',
#   '801',
#   '-',
#   '-']]

# %%
for idx, one in enumerate(all_data[0]):
    print(one[:-2])
    all_data[0][idx] = one[:-2]
dict_dat = { "국가":all_data[0][:91], 
             "확진자":all_data[1][:91],
             "치료중":all_data[2][:91],
             "사망자":all_data[3][:91],
             "완치":all_data[4][:91], 
             "치명(%)":all_data[5][:91],
             "완치(%)":all_data[6][:91],
             "발생률":all_data[7][:91], 
             "인구수":all_data[8][:91], 
             "국토면적":land_list}
dat = pd.DataFrame(dict_dat)
dat
# Out:
# 인
#
#
# 나
# 방
#
#
#
# 에
#
#
#
# 콩고민
#
#
#
#
#
#
#
#
# 남아프리카
#
#
#
#
#
#
# 아
#
#
# 우
#
# 아프
#
#
#
# 사우디
# 우즈
#
#
# 말
#
#
#
#
# 베
# 마다
#
# 코트
#
#
#
#
# 부르
#
#
#
#
# 카
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 도미니카
#
#
#
#
# 아제
#
#
# 아랍에
#
# 타
#
# 오
# 파푸
#
#
#
#
# 시
#
#
#
#
#
#
#
# 키르
# 엘
#
#
#
# 콩
# 슬
#
#
# 팔
# 코
# 라
#
# 중앙아프리카
#
#
#
#
# 크
#
#
# 에
#
# 보스니아 헤르
#
# 아
#
#
#
# 리
#
#
#
#
#
# 북마
# 슬
# 기
#
#
#
# 적
# 트리니다드
# 에
#
#
#
# 에
#
#
#
#
#
#
# 솔로
#
# 몬
# 룩
#
#
# 카
#
# 몰타
#
#
#
#
# 마
# 아
#
# 프랑스령
# 바
# 뉴칼
# 프랑스령 폴
#
# 상투메
#
# 세인
#
# 미크
#
# 세인트빈센트
#
#
# 앤티가
#
#
# 도미니
# 케이
#
# 마
#
# 세인트키츠
# 페
# 신
#
# 터크스 케이커
# 세인트
# 리히
#
#
# 영국령 버진
# 카리브
#
# 생바
# 세인
# 생피에르
#
# 포클랜
# 바티
# 왈리스
# 잔담
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-8740202eb7ef> in <module>
#      11              "발생률":all_data[7][:91],
#      12              "인구수":all_data[8][:91],
# ---> 13              "국토면적":land_list}
#      14 dat = pd.DataFrame(dict_dat)
#      15 dat
#
# NameError: name 'land_list' is not defined

# %%
dat.to_csv("coronaboard_project_02.csv", index=False ,encoding='utf-8-sig')
os.listdir( os.getcwd() )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-13ca54af5e68> in <module>
# ----> 1 dat.to_csv("coronaboard_project_02.csv", index=False ,encoding='utf-8-sig')
#       2 os.listdir( os.getcwd() )
#
# NameError: name 'dat' is not defined

# %%
print(type(dat.loc[0:90]))
dat.loc[0:90]

# %%
from IPython.display import display, Image
import os, warnings
import re
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
import time
from selenium.webdriver import ActionChains
from urllib.request import urlopen
driver = webdriver.Chrome('./chromedriver_90')
url = 'https://namu.wiki/w/%EA%B5%AD%EA%B0%80%EB%B3%84%20%EA%B5%AD%ED%86%A0%20%EB%A9%B4%EC%A0%81%20%EC%88%9C%EC%9C%84'
driver.get(url)
