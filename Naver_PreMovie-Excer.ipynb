# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %%
url = "https://movie.naver.com/movie/running/premovie.nhn"
page = urlopen(url)
soup = BeautifulSoup(page, 'lxml')

# %%
soup_ul_li = soup.find("ul", class_="lst_detail_t1").find_all("li")
len(soup_ul_li)
# soup_ul_li
# Out:
# 1

# %%
tit=soup.find_all('div', class_="lst_wrap")
print(tit[1])
# Out:
# <div class="lst_wrap">
# <div class="day_t1">
# <strong>
# <span class="blind">yyyy.MM.dd (dayOfWeek)</span>
# <span class="n2"><span class="blind">2</span></span><span class="n0"><span class="blind">0</span></span><span class="n2"><span class="blind">2</span></span><span class="n1"><span class="blind">1</span></span><span class="dot"><span class="blind">.</span></span><span class="n0"><span class="blind">0</span></span><span class="n6"><span class="blind">6</span></span><span class="dot"><span class="blind">.</span></span><span class="n2"><span class="blind">2</span></span><span class="n3"><span class="blind">3</span></span>
# <span class="w4"></span>
# </strong>
# </div>
# <ul class="lst_detail_t1">
# <li>
# <div class="thumb">
# <a href="/movie/bi/mi/basic.nhn?code=204624"><img alt="킬러의 보디가드 2" onerror="this.src='https://ssl.pstatic.net/static/movie/2012/09/dft_img99x141.png'" src="https://movie-phinf.pstatic.net/20210610_93/1623286297858F5HGm_JPEG/movie_image.jpg?type=m99_141_2"/></a><!-- N=a:sol.img,r:2,i:204624 -->
# </div>
# <dl class="lst_dsc">
# <dt class="tit">
# <span class="ico_rating_18">청소년 관람불가</span>
# <a href="/movie/bi/mi/basic.nhn?code=204624">킬러의 보디가드 2</a>
# <!-- N=a:sol.title,r:2,i:204624 -->
# </dt>
# <dd class="star">
# <dl class="info_exp">
# <dt class="tit_t1">예매율</dt>
# <dd>
# <div class="star_t1 b_star">
# <span class="num">1.19</span><span class="txt">%</span>
# </div>
# <span class="split">|</span>
# </dd>
# <dt class="tit_t2">기대지수</dt>
# <dd>
# <div class="star_t1">
# <span class="ico_want">보고싶어요</span><em class="exp_cnt">1882</em><span class="ico_dnwant">글쎄요</span><em class="exp_cnt">41</em>
# </div>
# </dd>
# </dl>
# </dd>
# <dd>
# <dl class="info_txt1">
# <dt class="tit_t1">개요</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=19">액션</a><!-- N=a:sol.genre,r:1 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.nhn?genre=11">코미디</a><!-- N=a:sol.genre,r:2 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.nhn?genre=16">범죄</a><!-- N=a:sol.genre,r:3 -->
# </span>
# <span class="split">|</span>
# 								117분
#
#
#
# 								<span class="split">|</span>
# 								2021.06.23 개봉
#
#
# 						</dd>
# <dt class="tit_t2">감독</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/bi/pi/basic.nhn?code=165567">패트릭 휴즈</a><!-- N=a:sol.director,r:1 -->
# </span>
# </dd>
# <dt class="tit_t3">출연</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/bi/pi/basic.nhn?code=9679">라이언 레이놀즈</a><!-- N=a:sol.actor,r:1 -->,
#
# 									<a href="/movie/bi/pi/basic.nhn?code=1408">사무엘 L. 잭슨</a><!-- N=a:sol.actor,r:2 -->,
#
# 									<a href="/movie/bi/pi/basic.nhn?code=1400">셀마 헤이엑</a><!-- N=a:sol.actor,r:3 -->,
#
# 									<a href="/movie/bi/pi/basic.nhn?code=2088">모건 프리먼</a><!-- N=a:sol.actor,r:4 -->,
#
# 									<a href="/movie/bi/pi/basic.nhn?code=93">안토니오 반데라스</a><!-- N=a:sol.actor,r:5 -->
# </span>
# </dd>
# </dl>
# </dd>
# <dd class="info_t1">
# <div class="btn_area">
# <a class="btn_rsv" href="/movie/bi/mi/reserve.nhn?code=204624">예매하기</a><!-- N=a:sol.ticket,r:2,i:204624 -->
# <span class="btn_t1">
# <a class="item1" href="/movie/bi/mi/photoView.nhn?code=204624">포토보기</a><!-- N=a:sol.photo,r:2,i:204624 -->
# <a class="item2" href="/movie/bi/mi/mediaView.nhn?code=204624&amp;mid=49453#tab">예고편</a><!-- N=a:sol.trailer,r:2,i:204624 -->
# </span>
# </div>
# </dd>
# </dl>
# </li>
# <li>
# <div class="thumb">
# <a href="/movie/bi/mi/basic.nhn?code=194205"><img alt="발신제한" onerror="this.src='https://ssl.pstatic.net/static/movie/2012/09/dft_img99x141.png'" src="https://movie-phinf.pstatic.net/20210609_138/1623220637715dKMK5_JPEG/movie_image.jpg?type=m99_141_2"/></a><!-- N=a:sol.img,r:3,i:194205 -->
# </div>
# <dl class="lst_dsc">
# <dt class="tit">
# <span class="ico_rating_15">15세 관람가</span>
# <a href="/movie/bi/mi/basic.nhn?code=194205">발신제한</a>
# <!-- N=a:sol.title,r:3,i:194205 -->
# </dt>
# <dd class="star">
# <dl class="info_exp">
# <dt class="tit_t1">예매율</dt>
# <dd>
# <div class="star_t1 b_star">
# <span class="num">2.33</span><span class="txt">%</span>
# </div>
# <span class="split">|</span>
# </dd>
# <dt class="tit_t2">기대지수</dt>
# <dd>
# <div class="star_t1">
# <span class="ico_want">보고싶어요</span><em class="exp_cnt">4850</em><span class="ico_dnwant">글쎄요</span><em class="exp_cnt">233</em>
# </div>
# </dd>
# </dl>
# </dd>
# <dd>
# <dl class="info_txt1">
# <dt class="tit_t1">개요</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=1">드라마</a><!-- N=a:sol.genre,r:1 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.nhn?genre=7">스릴러</a><!-- N=a:sol.genre,r:2 -->
# </span>
# <span class="split">|</span>
# 								94분
#
#
#
# 								<span class="split">|</span>
# 								2021.06.23 개봉
#
#
# 						</dd>
# <dt class="tit_t2">감독</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/bi/pi/basic.nhn?code=88133">김창주</a><!-- N=a:sol.director,r:1 -->
# </span>
# </dd>
# <dt class="tit_t3">출연</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/bi/pi/basic.nhn?code=155696">조우진</a><!-- N=a:sol.actor,r:1 -->,
#
# 									<a href="/movie/bi/pi/basic.nhn?code=370454">이재인</a><!-- N=a:sol.actor,r:2 -->,
#
# 									<a href="/movie/bi/pi/basic.nhn?code=38779">진경</a><!-- N=a:sol.actor,r:3 -->
# </span>
# </dd>
# </dl>
# </dd>
# <dd class="info_t1">
# <div class="btn_area">
# <a class="btn_rsv" href="/movie/bi/mi/reserve.nhn?code=194205">예매하기</a><!-- N=a:sol.ticket,r:3,i:194205 -->
# <span class="btn_t1">
# <a class="item1" href="/movie/bi/mi/photoView.nhn?code=194205">포토보기</a><!-- N=a:sol.photo,r:3,i:194205 -->
# <a class="item2" href="/movie/bi/mi/mediaView.nhn?code=194205&amp;mid=49548#tab">예고편</a><!-- N=a:sol.trailer,r:3,i:194205 -->
# <a class="item4" href="/movie/bi/mi/mediaView.nhn?code=194205&amp;mid=49656#tab">메이킹</a><!-- N=a:sol.making,r:3,i:194205 -->
# </span>
# </div>
# </dd>
# </dl>
# </li>
# <li>
# <div class="thumb">
# <a href="/movie/bi/mi/basic.nhn?code=199068"><img alt="메이드 인 루프탑" onerror="this.src='https://ssl.pstatic.net/static/movie/2012/09/dft_img99x141.png'" src="https://movie-phinf.pstatic.net/20210609_180/162321337877329BTf_JPEG/movie_image.jpg?type=m99_141_2"/></a><!-- N=a:sol.img,r:4,i:199068 -->
# </div>
# <dl class="lst_dsc">
# <dt class="tit">
# <span class="ico_rating_15">15세 관람가</span>
# <a href="/movie/bi/mi/basic.nhn?code=199068">메이드 인 루프탑</a>
# <!-- N=a:sol.title,r:4,i:199068 -->
# </dt>
# <dd class="star">
# <dl class="info_exp">
# <dt class="tit_t1">예매율</dt>
# <dd>
# <div class="star_t1 b_star">
# <span class="num">0.05</span><span class="txt">%</span>
# </div>
# <span class="split">|</span>
# </dd>
# <dt class="tit_t2">기대지수</dt>
# <dd>
# <div class="star_t1">
# <span class="ico_want">보고싶어요</span><em class="exp_cnt">198</em><span class="ico_dnwant">글쎄요</span><em class="exp_cnt">36</em>
# </div>
# </dd>
# </dl>
# </dd>
# <dd>
# <dl class="info_txt1">
# <dt class="tit_t1">개요</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=1">드라마</a><!-- N=a:sol.genre,r:1 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.nhn?genre=5">멜로/로맨스</a><!-- N=a:sol.genre,r:2 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.nhn?genre=11">코미디</a><!-- N=a:sol.genre,r:3 -->
# </span>
# <span class="split">|</span>
# 								87분
#
#
#
# 								<span class="split">|</span>
# 								2021.06.23 개봉
#
#
# 						</dd>
# <dt class="tit_t2">감독</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/bi/pi/basic.nhn?code=118352">김조광수</a><!-- N=a:sol.director,r:1 -->
# </span>
# </dd>
# <dt class="tit_t3">출연</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/bi/pi/basic.nhn?code=361981">이홍내</a><!-- N=a:sol.actor,r:1 -->,
#
# 									<a href="/movie/bi/pi/basic.nhn?code=392432">정휘</a><!-- N=a:sol.actor,r:2 -->,
#
# 									<a href="/movie/bi/pi/basic.nhn?code=331485">곽민규</a><!-- N=a:sol.actor,r:3 -->,
#
# 									<a href="/movie/bi/pi/basic.nhn?code=344909">염문경</a><!-- N=a:sol.actor,r:4 -->,
#
# 									<a href="/movie/bi/pi/basic.nhn?code=340104">이정은</a><!-- N=a:sol.actor,r:5 -->,
#
# 									<a href="/movie/bi/pi/basic.nhn?code=449336">강정우</a><!-- N=a:sol.actor,r:6 -->
# </span>
# </dd>
# </dl>
# </dd>
# <dd class="info_t1">
# <div class="btn_area">
# <a class="btn_rsv" href="/movie/bi/mi/reserve.nhn?code=199068">예매하기</a><!-- N=a:sol.ticket,r:4,i:199068 -->
# <span class="btn_t1">
# <a class="item1" href="/movie/bi/mi/photoView.nhn?code=199068">포토보기</a><!-- N=a:sol.photo,r:4,i:199068 -->
# <a class="item2" href="/movie/bi/mi/mediaView.nhn?code=199068&amp;mid=49657#tab">예고편</a><!-- N=a:sol.trailer,r:4,i:199068 -->
# </span>
# </div>
# </dd>
# </dl>
# </li>
# <li>
# <div class="thumb">
# <a href="/movie/bi/mi/basic.nhn?code=200353"><img alt="데이팅 앰버" onerror="this.src='https://ssl.pstatic.net/static/movie/2012/09/dft_img99x141.png'" src="https://movie-phinf.pstatic.net/20210610_162/1623314772686s6M7p_JPEG/movie_image.jpg?type=m99_141_2"/></a><!-- N=a:sol.img,r:5,i:200353 -->
# </div>
# <dl class="lst_dsc">
# <dt class="tit">
# <span class="ico_rating_15">15세 관람가</span>
# <a href="/movie/bi/mi/basic.nhn?code=200353">데이팅 앰버</a>
# <!-- N=a:sol.title,r:5,i:200353 -->
# </dt>
# <dd class="star">
# <dl class="info_exp">
# <dt class="tit_t2">기대지수</dt>
# <dd>
# <div class="star_t1">
# <span class="ico_want">보고싶어요</span><em class="exp_cnt">37</em><span class="ico_dnwant">글쎄요</span><em class="exp_cnt">3</em>
# </div>
# </dd>
# </dl>
# </dd>
# <dd>
# <dl class="info_txt1">
# <dt class="tit_t1">개요</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=11">코미디</a><!-- N=a:sol.genre,r:1 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.nhn?genre=1">드라마</a><!-- N=a:sol.genre,r:2 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.nhn?genre=5">멜로/로맨스</a><!-- N=a:sol.genre,r:3 -->
# </span>
# <span class="split">|</span>
# 								92분
#
#
#
# 								<span class="split">|</span>
# 								2021.06.23 개봉
#
#
# 						</dd>
# <dt class="tit_t2">감독</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/bi/pi/basic.nhn?code=173556">데이빗 프레인</a><!-- N=a:sol.director,r:1 -->
# </span>
# </dd>
# <dt class="tit_t3">출연</dt>
# <dd>
# <span class="link_txt">
# <a href="/movie/bi/pi/basic.nhn?code=449334">롤라 페티크루</a><!-- N=a:sol.actor,r:1 -->,
#
# 									<a href="/movie/bi/pi/basic.nhn?code=285689">피온 오쉐어</a><!-- N=a:sol.actor,r:2 -->,
#
# 									<a href="/movie/bi/pi/basic.nhn?code=92159">샤론 호갠</a><!-- N=a:sol.actor,r:3 -->,
#
# 									<a href="/movie/bi/pi/basic.nhn?code=338040">배리 워드</a><!-- N=a:sol.actor,r:4 -->,
#
# 									<a href="/movie/bi/pi/basic.nhn?code=259123">시모네 커비</a><!-- N=a:sol.actor,r:5 -->
# </span>
# </dd>
# </dl>
# </dd>
# <dd class="info_t1">
# <div class="btn_area">
# <span class="btn_t1">
# <a class="item1" href="/movie/bi/mi/photoView.nhn?code=200353">포토보기</a><!-- N=a:sol.photo,r:5,i:200353 -->
# <a class="item2" href="/movie/bi/mi/mediaView.nhn?code=200353&amp;mid=49632#tab">예고편</a><!-- N=a:sol.trailer,r:5,i:200353 -->
# </span>
# </div>
# </dd>
# </dl>
# </li>
# </ul>
# </div>

# %%
movie_title = []
for one in list:
    one_movie = one.find("a").text
    print(one_movie)
    movie_title.append(one_movie)
movie_title

# %%
soup_by_date = soup.find_all("div", class_="lst_wrap")
